# %%
from nilearn import datasets, plotting
from nilearn.input_data import NiftiSpheresMasker
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn.masking import compute_epi_mask
from nilearn.masking import apply_mask

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\nilearn\datasets\__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
#adhd_dataset = datasets.fetch_adhd(n_subjects=40)
atlas = datasets.fetch_atlas_msdl()
atlas_filename = atlas['maps']

from nilearn.input_data import NiftiMapsMasker
masker = NiftiMapsMasker(maps_img=atlas_filename, standardize=True,
                         memory='nilearn_cache', verbose=5)
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\npyio.py:2349: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)

# %%
from sklearn.decomposition import PCA
pca_data = []
variance = []
print('|'*40)
for i in range(94):
    func_filename =str('F:\\Data Analytics\\BTP I\\Data\\www.nitrc.org\\ir\\') + str(df.values[i,0])+str('_1\\rest_1\\NIfTI\\rest.nii.gz')
    time_series = masker.fit_transform(func_filename)

    pca = PCA(n_components=10)
    data = pca.fit_transform(time_series[:75,:])
    exp_variance = pca.explained_variance_ratio_
    pca_data.append(data)
    variance.append(exp_variance)
    #print('|',end='')
# Out:
# ||||||||||||||||||||||||||||||||||||||||
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1018959_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5D2D68>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1018959_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.5s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# [Memory]51.7s, 0.9min   : Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1043241_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1043241_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.6s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1266183_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1266183_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1535233_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E631DA0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1535233_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.5s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1541812_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093DB8BD30>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1541812_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1577042_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC128>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1577042_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.1s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1594156_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002096A70B748>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1594156_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\nilearn\input_data\nifti_maps_masker.py:352: UserWarning: Persisting input arguments took 0.51s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   verbose=self.verbose)
# _______________________________________________filter_and_extract - 4.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1623716_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002096A70B748>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1623716_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1638334_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E609D68>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1638334_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1652369_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E7D67F0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1652369_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1686265_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1686265_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1692275_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002096A65DDA0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1692275_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1735881_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002096A70BAC8>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1735881_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1779922_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E22BE48>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1779922_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.6s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1842819_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1842819_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\nilearn\input_data\nifti_maps_masker.py:352: UserWarning: Persisting input arguments took 0.52s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   verbose=self.verbose)
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1846346_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E649358>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1846346_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.5s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1873761_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093DB8B198>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1873761_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1962503_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1962503_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_img...
# resample_img(<nibabel.nifti1.Nifti1Image object at 0x000002093E649358>, interpolation='continuous', target_shape=(112, 112, 47), target_affine=array([[  -2.29    ,   -0.      ,   -0.      ,  127.095001],
#        [  -0.      ,    2.29    ,   -0.      , -127.094994],
#        [   0.      ,    0.      ,    3.      ,  -69.      ],
#        [   0.      ,    0.      ,    0.      ,    1.      ]]))
# _____________________________________________________resample_img - 3.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1988015_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1988015_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\nilearn\input_data\nifti_maps_masker.py:352: UserWarning: Persisting input arguments took 0.63s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   verbose=self.verbose)
# _______________________________________________filter_and_extract - 6.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# [Memory]165.0s, 2.7min  : Loading resample_img...
# ________________________________________resample_img cache loaded - 1.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_1996183_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E88C160>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_1996183_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.3s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20001_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC2B0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20001_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20002_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093DB8B198>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20002_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_img...
# resample_img(<nibabel.nifti1.Nifti1Image object at 0x000002093E88C080>, interpolation='continuous', target_shape=(96, 96, 47), target_affine=array([[  -2.67    ,   -0.      ,   -0.      ,  126.825005],
#        [  -0.      ,    2.67    ,   -0.      , -146.825012],
#        [   0.      ,    0.      ,    3.      ,  -69.      ],
#        [   0.      ,    0.      ,    0.      ,    1.      ]]))
# _____________________________________________________resample_img - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20003_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002096A70B748>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20003_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.7s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# [Memory]193.0s, 3.2min  : Loading resample_img...
# ________________________________________resample_img cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20008_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E7D6C50>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20008_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.2s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20010_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093DB8BD30>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20010_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.5s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20014_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E882C18>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20014_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.6s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_img...
# resample_img(<nibabel.nifti1.Nifti1Image object at 0x000002093E882438>, interpolation='continuous', target_shape=(96, 96, 47), target_affine=array([[  -2.67    ,   -0.      ,   -0.      ,  117.643906],
#        [  -0.      ,    2.67    ,   -0.      , -133.265106],
#        [   0.      ,    0.      ,    3.      ,  -69.      ],
#        [   0.      ,    0.      ,    0.      ,    1.      ]]))
# _____________________________________________________resample_img - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20015_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093DB8BD30>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20015_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.2s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# [Memory]220.5s, 3.7min  : Loading resample_img...
# ________________________________________resample_img cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20016_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093C2597B8>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20016_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.2s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20017_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5D22E8>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20017_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.6s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_img...
# resample_img(<nibabel.nifti1.Nifti1Image object at 0x000002093E5DC0F0>, interpolation='continuous', target_shape=(96, 96, 47), target_affine=array([[  -2.67    ,   -0.      ,   -0.      ,  124.825005],
#        [  -0.      ,    2.67    ,   -0.      , -141.825012],
#        [   0.      ,    0.      ,    3.      ,  -65.      ],
#        [   0.      ,    0.      ,    0.      ,    1.      ]]))
# _____________________________________________________resample_img - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20021_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093C2597B8>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20021_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.3s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_img...
# resample_img(<nibabel.nifti1.Nifti1Image object at 0x000002093E5DC2B0>, interpolation='continuous', target_shape=(96, 96, 47), target_affine=array([[  -2.67    ,   -0.      ,   -0.      ,  119.825005],
#        [  -0.      ,    2.67    ,   -0.      , -144.825012],
#        [   0.      ,    0.      ,    3.      ,  -51.      ],
#        [   0.      ,    0.      ,    0.      ,    1.      ]]))
# _____________________________________________________resample_img - 2.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_20022_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002096A65DDA0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_20022_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.4s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# Resampling maps
# [Memory]250.5s, 4.2min  : Loading resample_img...
# ________________________________________resample_img cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_2014113_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E631DA0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_2014113_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.8s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ...
# _______________________________________________filter_and_extract - 4.7s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_6346605_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E882208>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_6346605_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.1s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_6453038_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E879080>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_6453038_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.2s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_7129258_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093DB8B198>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_7129258_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.1s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_7415617_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5D2D68>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_7415617_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_7774305_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5FA550>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_7774305_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.6s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_8083695_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5FA550>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_8083695_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.1s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_8263351_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E88CFD0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_8263351_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_8337695_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E88CFD0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_8337695_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.5s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_8432725_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E631DA0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_8432725_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.0s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_8628223_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093C2597B8>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_8628223_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.5s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_8658218_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093E5DC0F0>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_8658218_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.9s, 0.1min
# [NiftiMapsMasker.fit_transform] loading regions from C:\Users\hp\nilearn_data\msdl_atlas\MSDL_rois\msdl_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract(('F:\\Data Analytics\\BTP '
#  'I\\Data\\www.nitrc.org\\ir\\KKI_9922944_1\\rest_1\\NIfTI\\rest.nii.gz'),
# <nilearn.input_data.nifti_maps_masker._ExtractionFunctor object at 0x000002093C2597B8>,
# { 'allow_overlap': True,
#   'detrend': False,
#   'dtype': None,
#   'high_pass': None,
#   'high_variance_confounds': False,
#   'low_pass': None,
#   'maps_img': 'C:\\Users\\hp/nilearn_data\\msdl_atlas\\MSDL_rois\\msdl_rois.nii',
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   'standardize_confounds': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=5)
# [NiftiMapsMasker.transform_single_imgs] Loading data from F:\Data Analytics\BTP I\Data\www.nitrc.org\ir\KKI_9922944_1\rest_1\NIfTI\rest.nii.gz
# [NiftiMapsMasker.transform_single_imgs] Extracting region signals
# [NiftiMapsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 4.9s, 0.1min

# %%
################## SAVING DATA ######################
import pickle
with open("Data/kki_pca_msdl.txt", "wb") as fp: 
    pickle.dump(pca_data, fp)
with open("Data/kki_variance_msdl.txt", "wb") as fp: 
    pickle.dump(variance, fp)

# %%
################### LOADING DATA ######################
import pickle
with open("Data/kki_pca_msdl.txt", "rb") as fp:
    pca_data = pickle.load(fp)
with open("Data/kki_variance_msdl.txt", "rb") as fp:
    variance = pickle.load(fp)

# %%
df = pd.read_csv('patients.csv',usecols =['Subject','Labels'])
df = df[26:26+94]
df.values[5,0]
# Out:
# 'KKI_1541812'

# %%
for i in range(len(pca_data)):
    pca_data[i] = pca_data[i].reshape(75,10,1) #Time, PCA, nsample
    
pca_data[90].shape
# Out:
# (75, 10, 1)

# %%
train = np.array(pca_data[:94])
#test = np.array(pca_data[80:])

y = df.values[:,1]
y_train = y[:94]
#y_test = y[80:]

# %%
################## TESTING WITH NILEARN 40 ###########################
import pickle
with open("Data/nilearn_pca_msdl.txt", "rb") as fp:
    data = pickle.load(fp)
    
for i in range(len(data)):
    data[i] = data[i].reshape(75,10,1) #Time, PCA, nsample
test = np.array(data)
test=np.asarray(test).astype(np.float32)
df2 = pd.read_csv('nilearn.csv',usecols =['adhd'])
y_test = df2['adhd']

# %%
import tensorflow as tf
import keras

from tensorflow.keras import datasets, layers, models
from keras.layers import Dropout

model = models.Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(75, 10, 1))) #Time, PCA, nsample
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(8, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.Conv2D(32, (3, 3), activation='relu'))
#model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 73, 8, 16)         160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 36, 4, 16)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 34, 2, 8)          1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 17, 1, 8)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 136)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               35072
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 69,417
# Trainable params: 69,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
train=np.asarray(train).astype(np.float32)
y_train=np.asarray(y_train).astype(np.int)

test=np.asarray(test).astype(np.float32)
y_test=np.asarray(y_test).astype(np.int)

# %%
batch_size = 5
num_epoch = 30
#model training
model_log = model.fit(train, y_train,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_data=(test, y_test), class_weight={0:1, 1:3})
# Out:
# Epoch 1/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 0.4903 - val_loss: 0.0000e+00 - val_accuracy: 0.3750
# Epoch 2/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5681 - val_loss: 0.0000e+00 - val_accuracy: 0.3500
# Epoch 3/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.4476 - val_loss: 0.0000e+00 - val_accuracy: 0.3500
# Epoch 4/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.4766 - val_loss: 0.0000e+00 - val_accuracy: 0.3500
# Epoch 5/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5217 - val_loss: 0.0000e+00 - val_accuracy: 0.3500
# Epoch 6/30
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5068 - val_loss: 0.0000e+00 - val_accuracy: 0.3500
# Epoch 7/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5310 - val_loss: 0.0000e+00 - val_accuracy: 0.4000
# Epoch 8/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5953 - val_loss: 0.0000e+00 - val_accuracy: 0.4000
# Epoch 9/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.4993 - val_loss: 0.0000e+00 - val_accuracy: 0.4000
# Epoch 10/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.6073 - val_loss: 0.0000e+00 - val_accuracy: 0.4250
# Epoch 11/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.6289 - val_loss: 0.0000e+00 - val_accuracy: 0.4250
# Epoch 12/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5352 - val_loss: 0.0000e+00 - val_accuracy: 0.4750
# Epoch 13/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 0.6208 - val_loss: 0.0000e+00 - val_accuracy: 0.4750
# Epoch 14/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5808 - val_loss: 0.0000e+00 - val_accuracy: 0.5000
# Epoch 15/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5813 - val_loss: 0.0000e+00 - val_accuracy: 0.5250
# Epoch 16/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.6108 - val_loss: 0.0000e+00 - val_accuracy: 0.5500
# Epoch 17/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5763 - val_loss: 0.0000e+00 - val_accuracy: 0.5500
# Epoch 18/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.6431 - val_loss: 0.0000e+00 - val_accuracy: 0.5250
# Epoch 19/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.6146 - val_loss: 0.0000e+00 - val_accuracy: 0.5250
# Epoch 20/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.7028 - val_loss: 0.0000e+00 - val_accuracy: 0.5250
# Epoch 21/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.6049 - val_loss: 0.0000e+00 - val_accuracy: 0.5250
# Epoch 22/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5235 - val_loss: 0.0000e+00 - val_accuracy: 0.5250
# Epoch 23/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.7564 - val_loss: 0.0000e+00 - val_accuracy: 0.5000
# Epoch 24/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.6872 - val_loss: 0.0000e+00 - val_accuracy: 0.4750
# Epoch 25/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.6938 - val_loss: 0.0000e+00 - val_accuracy: 0.4750
# Epoch 26/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.7032 - val_loss: 0.0000e+00 - val_accuracy: 0.5000
# Epoch 27/30
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.5894 - val_loss: 0.0000e+00 - val_accuracy: 0.5000
# Epoch 28/30
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5556 - val_loss: 0.0000e+00 - val_accuracy: 0.4750
# Epoch 29/30
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.6461 - val_loss: 0.0000e+00 - val_accuracy: 0.4750
# Epoch 30/30
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5986 - val_loss: 0.0000e+00 - val_accuracy: 0.4750

# %%
y_pred = model.predict_classes(train)
adhd = [0,0]
typic = [0,0]
for i in range(len(y_pred)):
    if(y_pred[i]==1 and y_train[i]==1):
        adhd[0] = adhd[0]+1
        adhd[1] = adhd[1]+1
    elif(y_pred[i]==0 and y_train[i]==1):
        adhd[1] = adhd[1]+1
    if(y_pred[i]==0 and y_train[i]==0):
        typic[0] = typic[0]+1
        typic[1] = typic[1]+1
    elif(y_pred[i]==1 and y_train[i]==0):
        typic[1] = typic[1]+1
    
print(adhd, typic)
# Out:
# [0, 25] [68, 69]

# %%
y_pred = model.predict_classes(test)
adhd = [0,0]
typic = [0,0]
for i in range(len(y_pred)):
    if(y_pred[i]==1 and y_test[i]==1):
        adhd[0] = adhd[0]+1
        adhd[1] = adhd[1]+1
    elif(y_pred[i]==0 and y_test[i]==1):
        adhd[1] = adhd[1]+1
    if(y_pred[i]==0 and y_test[i]==0):
        typic[0] = typic[0]+1
        typic[1] = typic[1]+1
    elif(y_pred[i]==1 and y_test[i]==0):
        typic[1] = typic[1]+1
    
print(adhd, typic)
# Out:
# [0, 20] [19, 20]

# %%
################## TESTING WITH NILEARN 40 ###########################
import pickle
with open("Data/nilearn_pca_msdl.txt", "rb") as fp:
    data = pickle.load(fp)
    
for i in range(len(data)):
    data[i] = data[i].reshape(75,10,1) #Time, PCA, nsample
test = np.array(data)
test=np.asarray(test).astype(np.float32)
df2 = pd.read_csv('nilearn.csv',usecols =['adhd'])
y_test = df2['adhd']
